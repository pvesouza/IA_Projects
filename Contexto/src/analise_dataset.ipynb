# %%
import warnings
warnings.filterwarnings("ignore")
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
import glob
import os
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from keras.callbacks import ModelCheckpoint
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn import tree, svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from Inputs_HDLAct import *
from Extrasensory_Manipulation import *

# %%
def get_filepath(file_dir,uuid):
    """This function gets the uuid of a subject and returns the file path for
    csv file of the subject
    
    Input:
        file_dir[string]: holds the directory of the desired file
        uuid[string]: 32 character string holding uuid
    
    Output:
        filepath[string]: a string of the address of the file that can be read easily
    
    """
    filename = '{}.features_labels.csv'.format(uuid)
    filepath = os.path.join(file_dir, filename)
    return(filepath)

# %% [markdown]
# # Leitura dos dados em .csv

# %%
def readdata_csv(data_dir):
    """This function gets the directory of the datasets and returns the dataset
    containing information of all 60 users
    
    Input:
        data_dir[string]: holds the directory of all the csv files (60)
        
    Output:
        grand_dataset[dict]: a dictionary of all the users' data. The format is:
            grand_dataset:{'uuid1': dataframe of csv file of the user 1
                           'uuid2': dataframe of csv file of the user 2
                           'uuid3': dataframe of csv file of the user 3
                           ...}
    
    """
    length_uuids = 36 # number of characters for each uuid
    
    __path = os.path.join(os.getcwd(), data_dir, "*.csv")           # Para fins de debug e encontrar a pasta correta ao qual o python estava se referenciando
    print(f"Pasta: {__path}")
    
    data_list = glob.glob("../data/*csv")
    print(f"Numero de arquivos encontrados {len(data_list)}")       # Imprime a quantidade de arquivos encontrada
    
    # grand_dataset is a dict. that holds the uuids and correspondong datast
    grand_dataset = {}
    lengthOFdataset = 0
    #Interação sobre todos os arquivos correspondentes a cada usuário (60 usuários para recuperar o uuid de cada um deles)
    for i in range(len(data_list)):
#    for i in range(5):
        # Lê a UUID de cada usuário para montar um dicionário com todas as UUIDS
        uuid = os.path.basename(data_list[i])[:length_uuids]
        print(f"UUID: {uuid}")
        
        dataset_ith = pd.read_csv(data_list[i])
        print(i,dataset_ith.shape)
        
        lengthOFdataset += len(dataset_ith)
        grand_dataset[uuid] = dataset_ith
        
    print(lengthOFdataset)
    
    return(grand_dataset)

# %% [markdown]
# # Leitura da pasta com todos os arquivos de cada usuário

# %%
def get_folds_uuids(fold_dir):
    """
    The function gets the directory where the the folds text files are located
    and returns a list of five np.arrays in each of them the uuids of the
    corresponding fold are stored.
    
    Input:
        fold_dir[string]: holds the directory in which folds are
    
    Output:
        folds_uuids[list]: a list of numpy arrays. Each array holds the uuids
                    in that fold. ex.
                    folds_uuids = [('uuid1','uuid2',...,'uuid12'),
                                   ('uuid13','uuid14',...,'uuid24'),
                                   ...,
                                   ('uuid49','uuid50',...,'uuid60')]
    """
    num_folds = 5
    # folds_uuids is gonna be a list of np.arrays. each array is a set of uuids
    folds_uuids = [0,1,2,3,4]
    # This loop reads all 5 test folds (iphone and android) and stores uuids
    for i in range(0,num_folds):
        filename = 'fold_{}_test_android_uuids.txt'.format(i)
        filepath = os.path.join(fold_dir, filename)
        # aux1 is the uuids of ith test fold for "android"
        aux1 = pd.read_csv(filepath,header=None,delimiter='\n')
        aux1 = aux1.values
        
        filename = 'fold_%s_test_iphone_uuids.txt' %i
        filepath = os.path.join(fold_dir, filename)
        # aux2 is the uuids of ith test fold for "iphone"
        aux2 = pd.read_csv(filepath,header=None,delimiter='\n')
        aux2 = aux2.values
        
        # Then we concatenate them
        folds_uuids[i] = np.concatenate((aux1,aux2),axis=0)
        
    return(folds_uuids)

# %% [markdown]
# # Determinando o range dos sensores

# %%
def sensors():
    """This function sets the ranges of the various sensors"""
    Sensor = {}
    Sensor['Acc'] = list(range(1,27))
    Sensor['Gyro'] = list(range(27,53))
    Sensor['Mag'] = list(range(53,84))
    Sensor['W_acc'] = list(range(84,130))
    Sensor['Compass'] = list(range(130,139))
    Sensor['Loc'] = list(range(139,156))
    Sensor['Aud'] = list(range(156,182))
    Sensor['AP'] = list(range(182,184))
    Sensor['PS'] = list(np.append(range(184,210),range(218,226)))
    return(Sensor)

# %%
def activities():
    activity = {}
    activity['label:LYING_DOWN'] = 226
    activity['label:SITTING'] = 227
    activity['label:FIX_walking'] = 228
    activity['label:FIX_running'] = 229
    activity['label:BICYCLING'] = 230
    activity['label:SLEEPING'] = 231
    activity['label:OR_indoors'] = 236
    activity['label:OR_outside'] = 237
    activity['label:IN_A_CAR'] = 238
    activity['label:ON_A_BUS'] = 239
    activity['label:DRIVE_-_I_M_THE_DRIVER'] = 240
    activity['label:DRIVE_-_I_M_A_PASSENGER'] = 241
    activity['label:PHONE_IN_POCKET'] = 244
    activity['label:PHONE_IN_HAND'] = 272
    activity['label:PHONE_IN_BAG'] = 273
    activity['label:PHONE_ON_TABLE'] = 274
    return(activity)

# %% [markdown]
# # Função para limpeza dos dados
# Essa função foi refatorada para evitar que classes fossem repetidas em uma mesma situação dos sensores e
# caso não haja nenhuma observação dentre os labels utilizados realizar uma limpeza nos dados e retornar o X e o Y de treinamento para cada caso

# %%
def data_cleaner(dataset, feature_set_range, parent_labels):
    features = dataset.iloc[:,feature_set_range]  #add fillna after this line
    labels = dataset[parent_labels]
    # Junta os labels com as features para formar o dataset que será utilizado nos modelos
    raw_data = pd.concat([features,labels],axis=1)
    # Retira do dataset as linhas que contenham elementos que não são números
    raw_data.dropna(inplace=True)
    df_labels = raw_data.iloc[:,len(feature_set_range):]

    df_labels_values = df_labels.values
    df_labels_values_my = df_labels_values.astype(int)

    #print('My float: {}'.format(df_labels_values.shape))
    #print('My int: {}'.format(df_labels_values_my.shape))

    row, column = df_labels_values_my.shape
    cont = 0
    list_labels = []
    indices = []
    missing_indexes = [] # lista de indices que não pertencem a nenhuma classe

    for i in range(row):
        indices.append(i)
        for c in range(column):
            value = df_labels_values_my[i][c]
            # debug para saber se quebrou
            if value != 1:
                if value != 0:
                    print("Quebrou")
        
            if value == 1:
                cont += 1
        # Testa se ocorreu um missing indice
        if cont == 0:
            missing_indexes.append(i)
        cont = 0

    # A diferença acontece porque há linhas em que as amostras não pertencem a classe alguma
    #print("Tamanho: {}".format(len(list_labels)))
    #print("Missing: {}".format(len(missing_indexes)))
    #print("Indices: {}".format(len(indices)))

    # Conficurando o novo dataset e deletando as linhas que não pertencem a nenhuma classe existente
    raw_data['indice'] = np.array(indices).reshape(raw_data.shape[0])
    raw_data.set_index('indice', inplace=True)
    raw_data_treated =  raw_data.drop(raw_data.index[missing_indexes])

    df_labels['indice'] = np.array(indices).reshape(raw_data.shape[0])
    df_labels.set_index('indice', inplace=True)
    df_labels_treated = df_labels.drop(df_labels.index[missing_indexes])

    #print("Shape das features tratadas {}".format(raw_data_treated.shape))
    #print("Shape dos labels tratados {}".format(df_labels_treated.shape))

    # Salvando uma coluna para os labels de cada classe
    df_labels_values = df_labels_treated.values
    df_labels_values_my = df_labels_values.astype(int)

    row,column = df_labels_values_my.shape

    print(row)
    print(column)

    for i in range(row):
        for c in range(column):
            value = df_labels_values_my[i][c]
            if value == 1:
                list_labels.append(c)
                break
            
    #print("Lista de Labels: {}".format(len(list_labels)))
            
    #Determinando o X_parent
    X_parent = raw_data_treated.iloc[:,range(0, len(feature_set_range))]
    X_parent = preprocessing.scale(X_parent, axis=0)
    y_parent = np.array(list_labels).reshape(X_parent.shape[0]) 
    
    return X_parent, y_parent

# %% [markdown]
# # Função utilizada para avaliação dos modelos

# %%
def return_accuracy(clf, y_test, x_test):
    #y_pred = clf.predict_classes(X_test) #Esta função foi descontinuada
    y_pred = clf.predict(x_test)
    classes_x = np.argmax(y_pred,axis=1)
    #print(classes_x)
    f1_accuracy = f1_score(y_test, classes_x, average='macro')
    BA_accuracy = balanced_accuracy_score(y_test, classes_x)
    accuracy = accuracy_score(y_test, classes_x)
    return accuracy, f1_accuracy, BA_accuracy

# %% [markdown]
# # Função para treinamento de um classificador utilizando o Keras

# %%
def run_dnn(x_train, y_train, n_out = 6):
    clf = Sequential()
    clf.add(Dense(128, input_dim=len(feature_set_range), activation='relu'))
    clf.add(Dropout(drop_out_per))
    clf.add(Dense(64, activation='relu'))
    clf.add(Dense(n_out, activation='softmax'))

    clf.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    clf.fit(x_train, y_train, batch_size=nb_batch,  epochs=nb_epoch, validation_split = val_split, class_weight=None)#, callbacks=[checkpointer])
    
    return clf

# %% [markdown]
# # Montando o dataset

# %%
from Inputs_HDLAct import *
#reading all data and storing in "dataset" a DF
dataset_uuids = readdata_csv("./data/") 
    
uuids = list(dataset_uuids.keys())
    
#Combining the all users' data to dataset
dataset = dataset_uuids[uuids[0]]
    
for i in range(1,len(uuids)):
    dataset = pd.concat([dataset,dataset_uuids[uuids[i]]],axis=0)
    
sensors_list = sensors()
feature_set_range = []
    
for i in range(len(sensors_to_use)):
    feature_set_range += sensors_list[sensors_to_use[i]]
# Out:
# Pasta: /home/pedro/Documentos/WorkspaceProjetos/IA_Projects/Contexto/src/./data/*.csv
# Numero de arquivos encontrados 60
# UUID: 27E04243-B138-4F40-A164-F40B60165CF3
# 0 (4927, 278)
# UUID: 83CF687B-7CEC-434B-9FE8-00C3D5799BE6
# 1 (9539, 278)
# UUID: 11B5EC4D-4133-4289-B475-4E737182A406
# 2 (8845, 278)
# UUID: D7D20E2E-FC78-405D-B346-DBD3FD8FC92B
# 3 (6210, 278)
# UUID: 5EF64122-B513-46AE-BCF1-E62AAC285D2C
# 4 (3911, 278)
# UUID: CCAF77F0-FABB-4F2F-9E24-D56AD0C5A82F
# 5 (8472, 278)
# UUID: 9759096F-1119-4E19-A0AD-6F16989C7E1C
# 6 (9959, 278)
# UUID: F50235E0-DD67-4F2A-B00B-1F31ADA998B9
# 7 (2266, 278)
# UUID: 78A91A4E-4A51-4065-BDA7-94755F0BB3BB
# 8 (11996, 278)
# UUID: E65577C1-8D5D-4F70-AF23-B3ADB9D3DBA3
# 9 (3441, 278)
# UUID: 3600D531-0C55-44A7-AE95-A7A38519464E
# 10 (5203, 278)
# UUID: 7CE37510-56D0-4120-A1CF-0E23351428D2
# 11 (9761, 278)
# UUID: 99B204C0-DD5C-4BB7-83E8-A37281B8D769
# 12 (6038, 278)
# UUID: 1538C99F-BA1E-4EFB-A949-6C7C47701B20
# 13 (6549, 278)
# UUID: 5119D0F8-FCA8-4184-A4EB-19421A40DE0D
# 14 (6617, 278)
# UUID: 0A986513-7828-4D53-AA1F-E02D6DF9561B
# 15 (3960, 278)
# UUID: B7F9D634-263E-4A97-87F9-6FFB4DDCB36C
# 16 (9383, 278)
# UUID: 40E170A7-607B-4578-AF04-F021C3B0384A
# 17 (7649, 278)
# UUID: A5CDF89D-02A2-4EC1-89F8-F534FDABDD96
# 18 (6040, 278)
# UUID: 4E98F91F-4654-42EF-B908-A3389443F2E7
# 19 (3250, 278)
# UUID: CDA3BBF7-6631-45E8-85BA-EEB416B32A3C
# 20 (2860, 278)
# UUID: 00EABED2-271D-49D8-B599-1D4A09240601
# 21 (2287, 278)
# UUID: A76A5AF5-5A93-4CF2-A16E-62353BB70E8A
# 22 (7520, 278)
# UUID: 797D145F-3858-4A7F-A7C2-A4EB721E133C
# 23 (3593, 278)
# UUID: BE3CA5A6-A561-4BBD-B7C9-5DF6805400FC
# 24 (8309, 278)
# UUID: B9724848-C7E2-45F4-9B3F-A1F38D864495
# 25 (7626, 278)
# UUID: FDAA70A1-42A3-4E3F-9AE3-3FDA412E03BF
# 26 (4973, 278)
# UUID: CF722AA9-2533-4E51-9FEB-9EAC84EE9AAC
# 27 (3615, 278)
# UUID: B09E373F-8A54-44C8-895B-0039390B859F
# 28 (8134, 278)
# UUID: 806289BC-AD52-4CC1-806C-0CDB14D65EB6
# 29 (9242, 278)
# UUID: ECECC2AB-D32F-4F90-B74C-E12A1C69BBE2
# 30 (3530, 278)
# UUID: 24E40C4C-A349-4F9F-93AB-01D00FB994AF
# 31 (4771, 278)
# UUID: 59818CD2-24D7-4D32-B133-24C2FE3801E5
# 32 (5947, 278)
# UUID: 098A72A5-E3E5-4F54-A152-BBDA0DF7B694
# 33 (6813, 278)
# UUID: 81536B0A-8DBF-4D8A-AC24-9543E2E4C8E0
# 34 (6407, 278)
# UUID: A5A30F76-581E-4757-97A2-957553A2C6AA
# 35 (1667, 278)
# UUID: 1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842
# 36 (7375, 278)
# UUID: 59EEFAE0-DEB0-4FFF-9250-54D2A03D0CF2
# 37 (7542, 278)
# UUID: 7D9BB102-A612-4E2A-8E22-3159752F55D8
# 38 (1600, 278)
# UUID: 61976C24-1C50-4355-9C49-AAE44A7D09F6
# 39 (8730, 278)
# UUID: 86A4F379-B305-473D-9D83-FC7D800180EF
# 40 (10738, 278)
# UUID: BEF6C611-50DA-4971-A040-87FB979F3FC1
# 41 (3451, 278)
# UUID: 5152A2DF-FAF3-4BA8-9CA9-E66B32671A53
# 42 (6617, 278)
# UUID: 8023FE1A-D3B0-4E2C-A57A-9321B7FC755F
# 43 (9189, 278)
# UUID: C48CE857-A0DD-4DDB-BEA5-3A25449B2153
# 44 (5092, 278)
# UUID: 96A358A0-FFF2-4239-B93E-C7425B901B47
# 45 (5819, 278)
# UUID: 9DC38D04-E82E-4F29-AB52-B476535226F2
# 46 (9686, 278)
# UUID: A7599A50-24AE-46A6-8EA6-2576F1011D81
# 47 (3898, 278)
# UUID: 33A85C34-CFE4-4732-9E73-0A7AC861B27A
# 48 (6172, 278)
# UUID: 665514DE-49DC-421F-8DCB-145D0B2609AD
# 49 (9167, 278)
# UUID: 136562B6-95B2-483D-88DC-065F28409FD2
# 50 (6218, 278)
# UUID: 61359772-D8D8-480D-B623-7C636EAD0C81
# 51 (6079, 278)
# UUID: 2C32C23E-E30C-498A-8DD2-0EFB9150A02E
# 52 (8516, 278)
# UUID: CA820D43-E5E2-42EF-9798-BE56F776370B
# 53 (7865, 278)
# UUID: 481F4DD2-7689-43B9-A2AA-C8772227162B
# 54 (6691, 278)
# UUID: 0BFC35E2-4817-4865-BFA7-764742302A2D
# 55 (3108, 278)
# UUID: 4FC32141-E888-4BFF-8804-12559A491D8C
# 56 (4979, 278)
# UUID: 1155FF54-63D3-4AB2-9863-8385D0BD0A13
# 57 (2685, 278)
# UUID: 74B86067-5D4B-43CF-82CF-341B76BEA0F4
# 58 (7298, 278)
# UUID: 0E6184E1-90C0-48EE-B25A-F1ECB7B9714E
# 59 (7521, 278)
# 377346

# %% [markdown]
# # Classificador para 6 classes

# %%
# Labels Utilizadas para seis classes
parent_labels = ['label:COOKING','label:SITTING','label:LYING_DOWN','label:FIX_running','label:FIX_walking','label:BICYCLING']

for i in range(len(parent_labels)):
    data = dataset[parent_labels[i]]
    print(parent_labels[i])
    #print(data.value_counts())
# Out:
# label:COOKING
# label:SITTING
# label:LYING_DOWN
# label:FIX_running
# label:FIX_walking
# label:BICYCLING

# %% [markdown]
# ## Pre-Processamento dos dados

# %%
X_parent, y_parent = data_cleaner(dataset, feature_set_range, parent_labels)
print(X_parent.shape)
print(y_parent.shape)
# Out:
# 6065
# 6
# (6065, 217)
# (6065,)

# %% [markdown]
# ## Observação dos dados

# %%
y_df = pd.DataFrame(y_parent)
print(y_df.value_counts())
# Out:
# 2    2500
# 1    2372
# 5     571
# 4     396
# 0     177
# 3      49
# dtype: int64

# %%
#Separando em treino e teste
seed = np.random.seed(5)
X_train, X_test, y_train, y_test = train_test_split(X_parent, y_parent, test_size=test_split, random_state = seed, stratify=y_parent)

# %%
# Definindo a estratégia de oversample
counter = Counter(y_train)
print(counter)
oversample = SMOTE(sampling_strategy={2:2000, 1:1909, 0:200, 5:600, 4:450, 3:50})
#Aplicando a reamostragem nos conjuntos X e Y
X_over, y_over = oversample.fit_resample(X_train, y_train)
print(y_over.shape)
# Out:
# Counter({2: 2000, 1: 1897, 5: 457, 4: 317, 0: 142, 3: 39})
# (5209,)

# %%
#Rodando o código sem oversample com seis labels
model_6 = run_dnn(X_train, y_train)
# Out:
# Epoch 1/50
# 461/461 [==============================] - 2s 5ms/step - loss: 0.5514 - accuracy: 0.8169 - val_loss: 0.3172 - val_accuracy: 0.8889
# Epoch 2/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.3096 - accuracy: 0.8935 - val_loss: 0.2658 - val_accuracy: 0.9012
# Epoch 3/50
# 461/461 [==============================] - 2s 3ms/step - loss: 0.2531 - accuracy: 0.9089 - val_loss: 0.2725 - val_accuracy: 0.9053
# Epoch 4/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.2114 - accuracy: 0.9245 - val_loss: 0.2809 - val_accuracy: 0.9177
# Epoch 5/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.1834 - accuracy: 0.9334 - val_loss: 0.2616 - val_accuracy: 0.9218
# Epoch 6/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.1692 - accuracy: 0.9356 - val_loss: 0.2247 - val_accuracy: 0.9218
# Epoch 7/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.1460 - accuracy: 0.9438 - val_loss: 0.2290 - val_accuracy: 0.9136
# Epoch 8/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.1456 - accuracy: 0.9477 - val_loss: 0.2135 - val_accuracy: 0.9218
# Epoch 9/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.1210 - accuracy: 0.9557 - val_loss: 0.2017 - val_accuracy: 0.9218
# Epoch 10/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.1186 - accuracy: 0.9549 - val_loss: 0.2350 - val_accuracy: 0.9218
# Epoch 11/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.1041 - accuracy: 0.9646 - val_loss: 0.2453 - val_accuracy: 0.9342
# Epoch 12/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.1055 - accuracy: 0.9603 - val_loss: 0.2894 - val_accuracy: 0.9218
# Epoch 13/50
# 461/461 [==============================] - 2s 5ms/step - loss: 0.0969 - accuracy: 0.9640 - val_loss: 0.2717 - val_accuracy: 0.9136
# Epoch 14/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0870 - accuracy: 0.9709 - val_loss: 0.3215 - val_accuracy: 0.9095
# Epoch 15/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0749 - accuracy: 0.9750 - val_loss: 0.2673 - val_accuracy: 0.9383
# Epoch 16/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0841 - accuracy: 0.9664 - val_loss: 0.2919 - val_accuracy: 0.9342
# Epoch 17/50
# 461/461 [==============================] - 2s 5ms/step - loss: 0.0685 - accuracy: 0.9748 - val_loss: 0.2452 - val_accuracy: 0.9300
# Epoch 18/50
# 461/461 [==============================] - 2s 3ms/step - loss: 0.0840 - accuracy: 0.9683 - val_loss: 0.2398 - val_accuracy: 0.9383
# Epoch 19/50
# 461/461 [==============================] - 1s 3ms/step - loss: 0.0679 - accuracy: 0.9744 - val_loss: 0.2599 - val_accuracy: 0.9383
# Epoch 20/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0608 - accuracy: 0.9785 - val_loss: 0.2719 - val_accuracy: 0.9424
# Epoch 21/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0591 - accuracy: 0.9764 - val_loss: 0.2777 - val_accuracy: 0.9465
# Epoch 22/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0570 - accuracy: 0.9796 - val_loss: 0.3249 - val_accuracy: 0.9342
# Epoch 23/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0651 - accuracy: 0.9768 - val_loss: 0.3106 - val_accuracy: 0.9300
# Epoch 24/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0519 - accuracy: 0.9809 - val_loss: 0.2964 - val_accuracy: 0.9177
# Epoch 25/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0515 - accuracy: 0.9813 - val_loss: 0.2556 - val_accuracy: 0.9300
# Epoch 26/50
# 461/461 [==============================] - 2s 5ms/step - loss: 0.0501 - accuracy: 0.9829 - val_loss: 0.2632 - val_accuracy: 0.9300
# Epoch 27/50
# 461/461 [==============================] - 2s 5ms/step - loss: 0.0480 - accuracy: 0.9831 - val_loss: 0.2658 - val_accuracy: 0.9342
# Epoch 28/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0514 - accuracy: 0.9833 - val_loss: 0.3278 - val_accuracy: 0.9342
# Epoch 29/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0501 - accuracy: 0.9811 - val_loss: 0.3195 - val_accuracy: 0.9465
# Epoch 30/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0449 - accuracy: 0.9824 - val_loss: 0.3409 - val_accuracy: 0.9300
# Epoch 31/50
# 461/461 [==============================] - 2s 5ms/step - loss: 0.0424 - accuracy: 0.9837 - val_loss: 0.3832 - val_accuracy: 0.9259
# Epoch 32/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0445 - accuracy: 0.9835 - val_loss: 0.4008 - val_accuracy: 0.9300
# Epoch 33/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0359 - accuracy: 0.9852 - val_loss: 0.3966 - val_accuracy: 0.9300
# Epoch 34/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0406 - accuracy: 0.9855 - val_loss: 0.5522 - val_accuracy: 0.9259
# Epoch 35/50
# 461/461 [==============================] - 3s 6ms/step - loss: 0.0475 - accuracy: 0.9822 - val_loss: 0.3922 - val_accuracy: 0.9342
# Epoch 36/50
# 461/461 [==============================] - 2s 5ms/step - loss: 0.0423 - accuracy: 0.9861 - val_loss: 0.3840 - val_accuracy: 0.9342
# Epoch 37/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0533 - accuracy: 0.9833 - val_loss: 0.2901 - val_accuracy: 0.9465
# Epoch 38/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0373 - accuracy: 0.9855 - val_loss: 0.3434 - val_accuracy: 0.9342
# Epoch 39/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0422 - accuracy: 0.9837 - val_loss: 0.4130 - val_accuracy: 0.9342
# Epoch 40/50
# 461/461 [==============================] - 4s 9ms/step - loss: 0.0485 - accuracy: 0.9826 - val_loss: 0.3230 - val_accuracy: 0.9506
# Epoch 41/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0418 - accuracy: 0.9855 - val_loss: 0.3532 - val_accuracy: 0.9342
# Epoch 42/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0347 - accuracy: 0.9872 - val_loss: 0.3651 - val_accuracy: 0.9342
# Epoch 43/50
# 461/461 [==============================] - 2s 5ms/step - loss: 0.0336 - accuracy: 0.9887 - val_loss: 0.3433 - val_accuracy: 0.9383
# Epoch 44/50
# 461/461 [==============================] - 3s 6ms/step - loss: 0.0341 - accuracy: 0.9887 - val_loss: 0.4160 - val_accuracy: 0.9424
# Epoch 45/50
# 461/461 [==============================] - 3s 6ms/step - loss: 0.0592 - accuracy: 0.9846 - val_loss: 0.3732 - val_accuracy: 0.9383
# Epoch 46/50
# 461/461 [==============================] - 3s 6ms/step - loss: 0.0377 - accuracy: 0.9863 - val_loss: 0.3251 - val_accuracy: 0.9342
# Epoch 47/50
# 461/461 [==============================] - 2s 5ms/step - loss: 0.0245 - accuracy: 0.9920 - val_loss: 0.4073 - val_accuracy: 0.9218
# Epoch 48/50
# 461/461 [==============================] - 2s 4ms/step - loss: 0.0402 - accuracy: 0.9868 - val_loss: 0.4446 - val_accuracy: 0.9383
# Epoch 49/50
# 461/461 [==============================] - 2s 5ms/step - loss: 0.0493 - accuracy: 0.9837 - val_loss: 0.4576 - val_accuracy: 0.9383
# Epoch 50/50
# 461/461 [==============================] - 2s 5ms/step - loss: 0.0381 - accuracy: 0.9878 - val_loss: 0.3861 - val_accuracy: 0.9342

# %%
# Resultados do modelo
print(return_accuracy(model_6, y_test, X_test))
# Out:
# (0.9307502061005771, 0.8596614073772559, 0.8270774615864557)

# %%
# Treinamento do modelo com oversampling utilizando SMOTE
model_6_over = run_dnn(X_over, y_over)
# Out:
# Epoch 1/50
# 495/495 [==============================] - 3s 5ms/step - loss: 0.5250 - accuracy: 0.8201 - val_loss: 0.4386 - val_accuracy: 0.8812
# Epoch 2/50
# 495/495 [==============================] - 2s 5ms/step - loss: 0.3087 - accuracy: 0.8943 - val_loss: 0.2952 - val_accuracy: 0.8966
# Epoch 3/50
# 495/495 [==============================] - 2s 3ms/step - loss: 0.2549 - accuracy: 0.9062 - val_loss: 0.2672 - val_accuracy: 0.9004
# Epoch 4/50
# 495/495 [==============================] - 2s 3ms/step - loss: 0.2045 - accuracy: 0.9250 - val_loss: 0.1942 - val_accuracy: 0.9272
# Epoch 5/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.1777 - accuracy: 0.9349 - val_loss: 0.1967 - val_accuracy: 0.9157
# Epoch 6/50
# 495/495 [==============================] - 3s 5ms/step - loss: 0.1735 - accuracy: 0.9376 - val_loss: 0.2464 - val_accuracy: 0.8966
# Epoch 7/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.1466 - accuracy: 0.9499 - val_loss: 0.1858 - val_accuracy: 0.9310
# Epoch 8/50
# 495/495 [==============================] - 2s 5ms/step - loss: 0.1176 - accuracy: 0.9576 - val_loss: 0.1283 - val_accuracy: 0.9579
# Epoch 9/50
# 495/495 [==============================] - 3s 6ms/step - loss: 0.1308 - accuracy: 0.9535 - val_loss: 0.1217 - val_accuracy: 0.9540
# Epoch 10/50
# 495/495 [==============================] - 2s 3ms/step - loss: 0.1074 - accuracy: 0.9602 - val_loss: 0.1133 - val_accuracy: 0.9693
# Epoch 11/50
# 495/495 [==============================] - 2s 3ms/step - loss: 0.1093 - accuracy: 0.9586 - val_loss: 0.2524 - val_accuracy: 0.8774
# Epoch 12/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0856 - accuracy: 0.9691 - val_loss: 0.0674 - val_accuracy: 0.9808
# Epoch 13/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0921 - accuracy: 0.9669 - val_loss: 0.0569 - val_accuracy: 0.9808
# Epoch 14/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0910 - accuracy: 0.9665 - val_loss: 0.0427 - val_accuracy: 0.9923
# Epoch 15/50
# 495/495 [==============================] - 2s 3ms/step - loss: 0.0819 - accuracy: 0.9719 - val_loss: 0.0453 - val_accuracy: 0.9808
# Epoch 16/50
# 495/495 [==============================] - 2s 3ms/step - loss: 0.0711 - accuracy: 0.9751 - val_loss: 0.0727 - val_accuracy: 0.9732
# Epoch 17/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0817 - accuracy: 0.9713 - val_loss: 0.0429 - val_accuracy: 0.9847
# Epoch 18/50
# 495/495 [==============================] - 2s 3ms/step - loss: 0.0676 - accuracy: 0.9747 - val_loss: 0.0646 - val_accuracy: 0.9770
# Epoch 19/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0632 - accuracy: 0.9757 - val_loss: 0.0413 - val_accuracy: 0.9847
# Epoch 20/50
# 495/495 [==============================] - 2s 5ms/step - loss: 0.0626 - accuracy: 0.9794 - val_loss: 0.0220 - val_accuracy: 0.9923
# Epoch 21/50
# 495/495 [==============================] - 3s 5ms/step - loss: 0.0479 - accuracy: 0.9810 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 22/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0708 - accuracy: 0.9772 - val_loss: 0.0562 - val_accuracy: 0.9770
# Epoch 23/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0642 - accuracy: 0.9764 - val_loss: 0.0417 - val_accuracy: 0.9885
# Epoch 24/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0573 - accuracy: 0.9794 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 25/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0558 - accuracy: 0.9786 - val_loss: 0.0539 - val_accuracy: 0.9847
# Epoch 26/50
# 495/495 [==============================] - 3s 5ms/step - loss: 0.0434 - accuracy: 0.9848 - val_loss: 0.0121 - val_accuracy: 0.9962
# Epoch 27/50
# 495/495 [==============================] - 3s 5ms/step - loss: 0.0543 - accuracy: 0.9824 - val_loss: 0.0223 - val_accuracy: 0.9962
# Epoch 28/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0461 - accuracy: 0.9830 - val_loss: 0.0160 - val_accuracy: 0.9962
# Epoch 29/50
# 495/495 [==============================] - 3s 6ms/step - loss: 0.0474 - accuracy: 0.9816 - val_loss: 0.0243 - val_accuracy: 0.9923
# Epoch 30/50
# 495/495 [==============================] - 3s 6ms/step - loss: 0.0476 - accuracy: 0.9846 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 31/50
# 495/495 [==============================] - 2s 5ms/step - loss: 0.0469 - accuracy: 0.9838 - val_loss: 0.0238 - val_accuracy: 0.9962
# Epoch 32/50
# 495/495 [==============================] - 2s 5ms/step - loss: 0.0405 - accuracy: 0.9863 - val_loss: 0.0197 - val_accuracy: 0.9962
# Epoch 33/50
# 495/495 [==============================] - 2s 5ms/step - loss: 0.0410 - accuracy: 0.9834 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 34/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0416 - accuracy: 0.9840 - val_loss: 0.0343 - val_accuracy: 0.9885
# Epoch 35/50
# 495/495 [==============================] - 3s 6ms/step - loss: 0.0396 - accuracy: 0.9867 - val_loss: 0.0425 - val_accuracy: 0.9847
# Epoch 36/50
# 495/495 [==============================] - 3s 5ms/step - loss: 0.0356 - accuracy: 0.9859 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 37/50
# 495/495 [==============================] - 3s 6ms/step - loss: 0.0521 - accuracy: 0.9836 - val_loss: 0.0219 - val_accuracy: 0.9847
# Epoch 38/50
# 495/495 [==============================] - 3s 6ms/step - loss: 0.0401 - accuracy: 0.9861 - val_loss: 0.0230 - val_accuracy: 0.9923
# Epoch 39/50
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0353 - accuracy: 0.9865 - val_loss: 0.0092 - val_accuracy: 0.9962
# Epoch 40/50
# 495/495 [==============================] - 3s 6ms/step - loss: 0.0400 - accuracy: 0.9848 - val_loss: 0.0123 - val_accuracy: 0.9962
# Epoch 41/50
# 495/495 [==============================] - 3s 6ms/step - loss: 0.0299 - accuracy: 0.9905 - val_loss: 0.0207 - val_accuracy: 0.9885
# Epoch 42/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0419 - accuracy: 0.9867 - val_loss: 0.0716 - val_accuracy: 0.9770
# Epoch 43/50
# 495/495 [==============================] - 2s 5ms/step - loss: 0.0269 - accuracy: 0.9907 - val_loss: 0.0164 - val_accuracy: 0.9923
# Epoch 44/50
# 495/495 [==============================] - 2s 5ms/step - loss: 0.0444 - accuracy: 0.9846 - val_loss: 0.0166 - val_accuracy: 0.9923
# Epoch 45/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0329 - accuracy: 0.9881 - val_loss: 0.0087 - val_accuracy: 0.9962
# Epoch 46/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0418 - accuracy: 0.9871 - val_loss: 0.0152 - val_accuracy: 0.9962
# Epoch 47/50
# 495/495 [==============================] - 3s 5ms/step - loss: 0.0329 - accuracy: 0.9887 - val_loss: 0.0163 - val_accuracy: 0.9962
# Epoch 48/50
# 495/495 [==============================] - 2s 4ms/step - loss: 0.0331 - accuracy: 0.9885 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 49/50
# 495/495 [==============================] - 2s 5ms/step - loss: 0.0298 - accuracy: 0.9895 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 50/50
# 495/495 [==============================] - 2s 5ms/step - loss: 0.0318 - accuracy: 0.9885 - val_loss: 0.0083 - val_accuracy: 1.0000

# %%
# Avaliação do modelo com oversampling
print(return_accuracy(model_6_over, y_test, X_test))
# Out:
# (0.9348722176422094, 0.8851271012499219, 0.8662567706185293)

# %% [markdown]
# # Classificador para 8 classes

# %%
# Treinamento com 8 labels
parent_labels_8 = ['label:COOKING','label:SITTING','label:LYING_DOWN','label:FIX_running','label:FIX_walking','label:BICYCLING', 'label:WATCHING_TV', 'label:SURFING_THE_INTERNET']

for i in range(len(parent_labels_8)):
    data = dataset[parent_labels_8[i]]
    print(parent_labels_8[i])
    #print(data.value_counts())
    
print(len(parent_labels_8))
# Out:
# label:COOKING
# label:SITTING
# label:LYING_DOWN
# label:FIX_running
# label:FIX_walking
# label:BICYCLING
# label:WATCHING_TV
# label:SURFING_THE_INTERNET
# 8

# %%
#Separação dos conjuntos para aplicação de acordo com os labels
X_parent_8, y_parent_8 = data_cleaner(dataset, feature_set_range, parent_labels_8)
print(X_parent_8.shape)
print(y_parent_8.shape)
# Out:
# 3557
# 8
# (3557, 217)
# (3557,)

# %%
#Observado o conjunto das classes
y_df_8 = pd.DataFrame(y_parent_8)
print(y_df_8.value_counts())
# Out:
# 1    1797
# 2     800
# 5     469
# 4     291
# 0     132
# 6      38
# 3      30
# dtype: int64

# %%
#Separando em treino e teste para 8 labels
X_train_8, X_test_8, y_train_8, y_test_8 = train_test_split(X_parent_8, y_parent_8, test_size=test_split, random_state = seed, stratify=y_parent_8)

# %%
# Definindo a estratégia de oversample para 8 labels
counter = Counter(y_train_8)
print(counter)
oversample = SMOTE(sampling_strategy={1:1437, 2:640, 5:375, 4:233, 0:130, 6:50, 3: 40})
#Aplicando a reamostragem nos conjuntos X e Y
X_over_8, y_over_8 = oversample.fit_resample(X_train_8, y_train_8)
print(y_over_8.shape)
# Out:
# Counter({1: 1437, 2: 640, 5: 375, 4: 233, 0: 106, 6: 30, 3: 24})
# (2905,)

# %%
#Treinamento do modelo com 8 classes
model8 = run_dnn(X_train_8, y_train_8, 7)
model8_over = run_dnn(X_over_8, y_over_8, 7)
# Out:
# Epoch 1/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.6286 - accuracy: 0.8013 - val_loss: 0.3247 - val_accuracy: 0.8951
# Epoch 2/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.3226 - accuracy: 0.8875 - val_loss: 0.2627 - val_accuracy: 0.9091
# Epoch 3/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.2540 - accuracy: 0.9071 - val_loss: 0.2535 - val_accuracy: 0.9091
# Epoch 4/50
# 271/271 [==============================] - 1s 3ms/step - loss: 0.2270 - accuracy: 0.9152 - val_loss: 0.2683 - val_accuracy: 0.9091
# Epoch 5/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.1745 - accuracy: 0.9367 - val_loss: 0.2560 - val_accuracy: 0.9021
# Epoch 6/50
# 271/271 [==============================] - 1s 5ms/step - loss: 0.1616 - accuracy: 0.9412 - val_loss: 0.2583 - val_accuracy: 0.8951
# Epoch 7/50
# 271/271 [==============================] - 1s 3ms/step - loss: 0.1464 - accuracy: 0.9474 - val_loss: 0.2593 - val_accuracy: 0.9301
# Epoch 8/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.1175 - accuracy: 0.9552 - val_loss: 0.2580 - val_accuracy: 0.8951
# Epoch 9/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.1063 - accuracy: 0.9604 - val_loss: 0.2557 - val_accuracy: 0.9091
# Epoch 10/50
# 271/271 [==============================] - 1s 5ms/step - loss: 0.0865 - accuracy: 0.9711 - val_loss: 0.2074 - val_accuracy: 0.9161
# Epoch 11/50
# 271/271 [==============================] - 1s 3ms/step - loss: 0.0856 - accuracy: 0.9645 - val_loss: 0.3278 - val_accuracy: 0.9161
# Epoch 12/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0987 - accuracy: 0.9637 - val_loss: 0.2654 - val_accuracy: 0.9091
# Epoch 13/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0694 - accuracy: 0.9748 - val_loss: 0.2571 - val_accuracy: 0.9161
# Epoch 14/50
# 271/271 [==============================] - 1s 3ms/step - loss: 0.1050 - accuracy: 0.9641 - val_loss: 0.3220 - val_accuracy: 0.9021
# Epoch 15/50
# 271/271 [==============================] - 1s 3ms/step - loss: 0.0697 - accuracy: 0.9734 - val_loss: 0.2720 - val_accuracy: 0.9231
# Epoch 16/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0564 - accuracy: 0.9800 - val_loss: 0.3154 - val_accuracy: 0.9091
# Epoch 17/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0588 - accuracy: 0.9789 - val_loss: 0.2786 - val_accuracy: 0.9301
# Epoch 18/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0418 - accuracy: 0.9878 - val_loss: 0.4004 - val_accuracy: 0.9021
# Epoch 19/50
# 271/271 [==============================] - 1s 3ms/step - loss: 0.0557 - accuracy: 0.9808 - val_loss: 0.3576 - val_accuracy: 0.9161
# Epoch 20/50
# 271/271 [==============================] - 1s 5ms/step - loss: 0.0540 - accuracy: 0.9789 - val_loss: 0.2964 - val_accuracy: 0.9231
# Epoch 21/50
# 271/271 [==============================] - 1s 5ms/step - loss: 0.0366 - accuracy: 0.9867 - val_loss: 0.2923 - val_accuracy: 0.9510
# Epoch 22/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0486 - accuracy: 0.9833 - val_loss: 0.2761 - val_accuracy: 0.9301
# Epoch 23/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0568 - accuracy: 0.9800 - val_loss: 0.3868 - val_accuracy: 0.9161
# Epoch 24/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0448 - accuracy: 0.9833 - val_loss: 0.3964 - val_accuracy: 0.9091
# Epoch 25/50
# 271/271 [==============================] - 1s 5ms/step - loss: 0.0412 - accuracy: 0.9845 - val_loss: 0.2607 - val_accuracy: 0.9441
# Epoch 26/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0417 - accuracy: 0.9856 - val_loss: 0.4814 - val_accuracy: 0.9161
# Epoch 27/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0292 - accuracy: 0.9896 - val_loss: 0.3379 - val_accuracy: 0.9301
# Epoch 28/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.0305 - accuracy: 0.9882 - val_loss: 0.4147 - val_accuracy: 0.9231
# Epoch 29/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0315 - accuracy: 0.9904 - val_loss: 0.3911 - val_accuracy: 0.9231
# Epoch 30/50
# 271/271 [==============================] - 1s 5ms/step - loss: 0.0285 - accuracy: 0.9922 - val_loss: 0.2673 - val_accuracy: 0.9371
# Epoch 31/50
# 271/271 [==============================] - 1s 5ms/step - loss: 0.0295 - accuracy: 0.9904 - val_loss: 0.3594 - val_accuracy: 0.9231
# Epoch 32/50
# 271/271 [==============================] - 1s 3ms/step - loss: 0.0218 - accuracy: 0.9930 - val_loss: 0.4059 - val_accuracy: 0.9161
# Epoch 33/50
# 271/271 [==============================] - 1s 5ms/step - loss: 0.0509 - accuracy: 0.9819 - val_loss: 0.3313 - val_accuracy: 0.9441
# Epoch 34/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0280 - accuracy: 0.9911 - val_loss: 0.3950 - val_accuracy: 0.9091
# Epoch 35/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0270 - accuracy: 0.9900 - val_loss: 0.2923 - val_accuracy: 0.9231
# Epoch 36/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0437 - accuracy: 0.9863 - val_loss: 0.3632 - val_accuracy: 0.9231
# Epoch 37/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0491 - accuracy: 0.9859 - val_loss: 0.2857 - val_accuracy: 0.9301
# Epoch 38/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0297 - accuracy: 0.9911 - val_loss: 0.2636 - val_accuracy: 0.9301
# Epoch 39/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0229 - accuracy: 0.9919 - val_loss: 0.3242 - val_accuracy: 0.9371
# Epoch 40/50
# 271/271 [==============================] - 1s 5ms/step - loss: 0.0422 - accuracy: 0.9893 - val_loss: 0.3860 - val_accuracy: 0.9371
# Epoch 41/50
# 271/271 [==============================] - 1s 5ms/step - loss: 0.0372 - accuracy: 0.9900 - val_loss: 0.2583 - val_accuracy: 0.9371
# Epoch 42/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0310 - accuracy: 0.9885 - val_loss: 0.3638 - val_accuracy: 0.9231
# Epoch 43/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0286 - accuracy: 0.9915 - val_loss: 0.2781 - val_accuracy: 0.9301
# Epoch 44/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0237 - accuracy: 0.9904 - val_loss: 0.2986 - val_accuracy: 0.9301
# Epoch 45/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0300 - accuracy: 0.9922 - val_loss: 0.2410 - val_accuracy: 0.9441
# Epoch 46/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0287 - accuracy: 0.9922 - val_loss: 0.2803 - val_accuracy: 0.9231
# Epoch 47/50
# 271/271 [==============================] - 1s 5ms/step - loss: 0.0394 - accuracy: 0.9882 - val_loss: 0.3095 - val_accuracy: 0.9161
# Epoch 48/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0338 - accuracy: 0.9900 - val_loss: 0.3906 - val_accuracy: 0.9301
# Epoch 49/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0418 - accuracy: 0.9870 - val_loss: 0.3162 - val_accuracy: 0.9231
# Epoch 50/50
# 271/271 [==============================] - 1s 4ms/step - loss: 0.0312 - accuracy: 0.9882 - val_loss: 0.4270 - val_accuracy: 0.9091
# Epoch 1/50
# 276/276 [==============================] - 2s 5ms/step - loss: 0.6178 - accuracy: 0.8036 - val_loss: 0.5761 - val_accuracy: 0.7260
# Epoch 2/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.3258 - accuracy: 0.8851 - val_loss: 0.3884 - val_accuracy: 0.8630
# Epoch 3/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.2599 - accuracy: 0.9021 - val_loss: 0.3499 - val_accuracy: 0.8767
# Epoch 4/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.1979 - accuracy: 0.9319 - val_loss: 0.2920 - val_accuracy: 0.9041
# Epoch 5/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.1735 - accuracy: 0.9340 - val_loss: 0.1966 - val_accuracy: 0.9589
# Epoch 6/50
# 276/276 [==============================] - 1s 3ms/step - loss: 0.1509 - accuracy: 0.9478 - val_loss: 0.2314 - val_accuracy: 0.9247
# Epoch 7/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.1348 - accuracy: 0.9514 - val_loss: 0.2131 - val_accuracy: 0.9110
# Epoch 8/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.1145 - accuracy: 0.9598 - val_loss: 0.2037 - val_accuracy: 0.9178
# Epoch 9/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.1026 - accuracy: 0.9616 - val_loss: 0.2470 - val_accuracy: 0.9178
# Epoch 10/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0995 - accuracy: 0.9667 - val_loss: 0.2994 - val_accuracy: 0.9041
# Epoch 11/50
# 276/276 [==============================] - 1s 3ms/step - loss: 0.0842 - accuracy: 0.9677 - val_loss: 0.1747 - val_accuracy: 0.9452
# Epoch 12/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0826 - accuracy: 0.9703 - val_loss: 0.1995 - val_accuracy: 0.9521
# Epoch 13/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0765 - accuracy: 0.9721 - val_loss: 0.2228 - val_accuracy: 0.9247
# Epoch 14/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0683 - accuracy: 0.9746 - val_loss: 0.1373 - val_accuracy: 0.9521
# Epoch 15/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0644 - accuracy: 0.9743 - val_loss: 0.2521 - val_accuracy: 0.9110
# Epoch 16/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0648 - accuracy: 0.9772 - val_loss: 0.1777 - val_accuracy: 0.9384
# Epoch 17/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0486 - accuracy: 0.9826 - val_loss: 0.2827 - val_accuracy: 0.9315
# Epoch 18/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0607 - accuracy: 0.9783 - val_loss: 0.2764 - val_accuracy: 0.9315
# Epoch 19/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0459 - accuracy: 0.9830 - val_loss: 0.2723 - val_accuracy: 0.9452
# Epoch 20/50
# 276/276 [==============================] - 2s 6ms/step - loss: 0.0341 - accuracy: 0.9877 - val_loss: 0.2258 - val_accuracy: 0.9384
# Epoch 21/50
# 276/276 [==============================] - 1s 3ms/step - loss: 0.0570 - accuracy: 0.9801 - val_loss: 0.2472 - val_accuracy: 0.9247
# Epoch 22/50
# 276/276 [==============================] - 1s 3ms/step - loss: 0.0581 - accuracy: 0.9786 - val_loss: 0.2836 - val_accuracy: 0.9315
# Epoch 23/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0456 - accuracy: 0.9826 - val_loss: 0.2439 - val_accuracy: 0.9315
# Epoch 24/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0392 - accuracy: 0.9848 - val_loss: 0.2660 - val_accuracy: 0.9315
# Epoch 25/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0403 - accuracy: 0.9841 - val_loss: 0.2707 - val_accuracy: 0.9452
# Epoch 26/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0367 - accuracy: 0.9859 - val_loss: 0.2215 - val_accuracy: 0.9315
# Epoch 27/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0400 - accuracy: 0.9880 - val_loss: 0.3135 - val_accuracy: 0.9315
# Epoch 28/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0369 - accuracy: 0.9873 - val_loss: 0.2352 - val_accuracy: 0.9452
# Epoch 29/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0355 - accuracy: 0.9877 - val_loss: 0.3102 - val_accuracy: 0.9384
# Epoch 30/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0454 - accuracy: 0.9851 - val_loss: 0.2917 - val_accuracy: 0.9247
# Epoch 31/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0360 - accuracy: 0.9880 - val_loss: 0.2414 - val_accuracy: 0.9315
# Epoch 32/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0310 - accuracy: 0.9899 - val_loss: 0.2281 - val_accuracy: 0.9315
# Epoch 33/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0377 - accuracy: 0.9891 - val_loss: 0.1827 - val_accuracy: 0.9384
# Epoch 34/50
# 276/276 [==============================] - 2s 6ms/step - loss: 0.0370 - accuracy: 0.9891 - val_loss: 0.2447 - val_accuracy: 0.9384
# Epoch 35/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0374 - accuracy: 0.9873 - val_loss: 0.3380 - val_accuracy: 0.9452
# Epoch 36/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0337 - accuracy: 0.9866 - val_loss: 0.2708 - val_accuracy: 0.9384
# Epoch 37/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0369 - accuracy: 0.9848 - val_loss: 0.3501 - val_accuracy: 0.9178
# Epoch 38/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0227 - accuracy: 0.9899 - val_loss: 0.3153 - val_accuracy: 0.9384
# Epoch 39/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0174 - accuracy: 0.9938 - val_loss: 0.3524 - val_accuracy: 0.9110
# Epoch 40/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0255 - accuracy: 0.9909 - val_loss: 0.3407 - val_accuracy: 0.9315
# Epoch 41/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0304 - accuracy: 0.9899 - val_loss: 0.3031 - val_accuracy: 0.9315
# Epoch 42/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0378 - accuracy: 0.9866 - val_loss: 0.2187 - val_accuracy: 0.9521
# Epoch 43/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0306 - accuracy: 0.9920 - val_loss: 0.2437 - val_accuracy: 0.9452
# Epoch 44/50
# 276/276 [==============================] - 2s 6ms/step - loss: 0.0173 - accuracy: 0.9946 - val_loss: 0.2429 - val_accuracy: 0.9384
# Epoch 45/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0335 - accuracy: 0.9913 - val_loss: 0.2595 - val_accuracy: 0.9315
# Epoch 46/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0306 - accuracy: 0.9906 - val_loss: 0.3375 - val_accuracy: 0.9247
# Epoch 47/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0365 - accuracy: 0.9873 - val_loss: 0.3087 - val_accuracy: 0.9315
# Epoch 48/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0212 - accuracy: 0.9931 - val_loss: 0.2899 - val_accuracy: 0.9452
# Epoch 49/50
# 276/276 [==============================] - 1s 5ms/step - loss: 0.0206 - accuracy: 0.9931 - val_loss: 0.3720 - val_accuracy: 0.9315
# Epoch 50/50
# 276/276 [==============================] - 1s 4ms/step - loss: 0.0391 - accuracy: 0.9873 - val_loss: 0.4091 - val_accuracy: 0.9247

# %%
# Avaliação dos modelos com 8 classes
print(return_accuracy(model8, y_test_8, X_test_8))
print(return_accuracy(model8_over, y_test_8, X_test_8))
# Out:
# (0.9030898876404494, 0.8375975595481103, 0.8243226936917326)
# (0.8960674157303371, 0.8062526178215632, 0.7750564309946189)

# %% [markdown]
# # Utilização do Modelo com 10 classes

# %%
# Treinamento com 10 labels
parent_labels_10 = ['label:COOKING','label:SITTING','label:LYING_DOWN','label:FIX_running','label:FIX_walking','label:BICYCLING', 'label:WATCHING_TV', 'label:SURFING_THE_INTERNET', 'label:COMPUTER_WORK', 'label:LOC_home']

for i in range(len(parent_labels_10)):
    data = dataset[parent_labels_10[i]]
    print(parent_labels_10[i])
    #print(data.value_counts())
    
print(len(parent_labels_10))
# Out:
# label:COOKING
# label:SITTING
# label:LYING_DOWN
# label:FIX_running
# label:FIX_walking
# label:BICYCLING
# label:WATCHING_TV
# label:SURFING_THE_INTERNET
# label:COMPUTER_WORK
# label:LOC_home
# 10

# %%
# Limpeza dos dados e seleção para aplicar ao modelo
X_parent_10, y_parent_10 = data_cleaner(dataset, feature_set_range, parent_labels_10)
print(X_parent_10.shape)
print(y_parent_10.shape)
# Out:
# 3138
# 10
# (3138, 217)
# (3138,)

# %%
# Observação da frequencia das classes
y_df_10 = pd.DataFrame(y_parent_10)
print(y_df_10.value_counts())
# Out:
# 1    1321
# 9     768
# 5     442
# 2     244
# 4     214
# 0     119
# 3      30
# dtype: int64

# %%
#Separando em treino e teste para 10 labels
X_train_10, X_test_10, y_train_10, y_test_10 = train_test_split(X_parent_10, y_parent_10, test_size=test_split, random_state = seed, stratify=y_parent_10)

# %%
# Definindo a estratégia de oversample para 8 labels
counter = Counter(y_train_10)
print(counter)
oversample = SMOTE(sampling_strategy={1:1057, 9:614, 5:400, 2:200, 4:200, 0:100, 3: 40})
#Aplicando a reamostragem nos conjuntos X e Y
X_over_10, y_over_10 = oversample.fit_resample(X_train_10, y_train_10)
print(y_over_10.shape)
# Out:
# Counter({1: 1057, 9: 614, 5: 354, 2: 195, 4: 171, 0: 95, 3: 24})
# (2611,)

# %%
# Treinamento dos modelos
model_10 = run_dnn(X_train_10, y_train_10, 10)
model_10_over = run_dnn(X_over_10, y_over_10, 10)
# Out:
# Epoch 1/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.9392 - accuracy: 0.7060 - val_loss: 0.7379 - val_accuracy: 0.7778
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.5223 - accuracy: 0.8234 - val_loss: 0.6162 - val_accuracy: 0.7937
# Epoch 3/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.4237 - accuracy: 0.8549 - val_loss: 0.6457 - val_accuracy: 0.7937
# Epoch 4/50
# 239/239 [==============================] - 1s 3ms/step - loss: 0.3511 - accuracy: 0.8775 - val_loss: 0.6237 - val_accuracy: 0.8095
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.3287 - accuracy: 0.8821 - val_loss: 0.6254 - val_accuracy: 0.8095
# Epoch 6/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.2753 - accuracy: 0.9014 - val_loss: 0.6098 - val_accuracy: 0.8254
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.2487 - accuracy: 0.9111 - val_loss: 0.5832 - val_accuracy: 0.8095
# Epoch 8/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.2147 - accuracy: 0.9253 - val_loss: 0.6021 - val_accuracy: 0.8175
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.1856 - accuracy: 0.9367 - val_loss: 0.6260 - val_accuracy: 0.8413
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.1603 - accuracy: 0.9379 - val_loss: 0.6459 - val_accuracy: 0.8016
# Epoch 11/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.1568 - accuracy: 0.9430 - val_loss: 0.6145 - val_accuracy: 0.8254
# Epoch 12/50
# 239/239 [==============================] - 1s 6ms/step - loss: 0.1381 - accuracy: 0.9488 - val_loss: 0.6620 - val_accuracy: 0.8095
# Epoch 13/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.1306 - accuracy: 0.9518 - val_loss: 0.7107 - val_accuracy: 0.8175
# Epoch 14/50
# 239/239 [==============================] - 2s 7ms/step - loss: 0.1178 - accuracy: 0.9581 - val_loss: 0.6534 - val_accuracy: 0.8254
# Epoch 15/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.1092 - accuracy: 0.9576 - val_loss: 0.6749 - val_accuracy: 0.8175
# Epoch 16/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.1089 - accuracy: 0.9597 - val_loss: 0.8880 - val_accuracy: 0.8016
# Epoch 17/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0966 - accuracy: 0.9643 - val_loss: 0.9130 - val_accuracy: 0.8016
# Epoch 18/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0847 - accuracy: 0.9719 - val_loss: 0.6931 - val_accuracy: 0.7937
# Epoch 19/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0843 - accuracy: 0.9732 - val_loss: 0.7932 - val_accuracy: 0.8016
# Epoch 20/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0846 - accuracy: 0.9761 - val_loss: 0.9310 - val_accuracy: 0.8175
# Epoch 21/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0944 - accuracy: 0.9639 - val_loss: 0.8799 - val_accuracy: 0.8016
# Epoch 22/50
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0836 - accuracy: 0.9744 - val_loss: 0.8084 - val_accuracy: 0.8175
# Epoch 23/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0871 - accuracy: 0.9761 - val_loss: 0.8103 - val_accuracy: 0.8254
# Epoch 24/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0707 - accuracy: 0.9778 - val_loss: 0.8939 - val_accuracy: 0.8333
# Epoch 25/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0523 - accuracy: 0.9832 - val_loss: 0.8903 - val_accuracy: 0.8254
# Epoch 26/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0639 - accuracy: 0.9820 - val_loss: 0.9538 - val_accuracy: 0.8175
# Epoch 27/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0552 - accuracy: 0.9782 - val_loss: 0.8436 - val_accuracy: 0.8333
# Epoch 28/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0542 - accuracy: 0.9820 - val_loss: 0.9639 - val_accuracy: 0.8016
# Epoch 29/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0431 - accuracy: 0.9878 - val_loss: 0.8887 - val_accuracy: 0.8571
# Epoch 30/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0467 - accuracy: 0.9845 - val_loss: 0.9144 - val_accuracy: 0.8095
# Epoch 31/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0380 - accuracy: 0.9874 - val_loss: 1.1057 - val_accuracy: 0.8254
# Epoch 32/50
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0587 - accuracy: 0.9815 - val_loss: 1.0295 - val_accuracy: 0.8175
# Epoch 33/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0463 - accuracy: 0.9866 - val_loss: 1.0192 - val_accuracy: 0.8016
# Epoch 34/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0433 - accuracy: 0.9866 - val_loss: 1.0869 - val_accuracy: 0.8095
# Epoch 35/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0659 - accuracy: 0.9820 - val_loss: 0.9853 - val_accuracy: 0.8095
# Epoch 36/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0559 - accuracy: 0.9815 - val_loss: 1.0442 - val_accuracy: 0.8016
# Epoch 37/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0619 - accuracy: 0.9811 - val_loss: 1.2558 - val_accuracy: 0.8095
# Epoch 38/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0610 - accuracy: 0.9811 - val_loss: 1.1089 - val_accuracy: 0.8095
# Epoch 39/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0429 - accuracy: 0.9849 - val_loss: 1.1748 - val_accuracy: 0.7778
# Epoch 40/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0419 - accuracy: 0.9836 - val_loss: 1.2157 - val_accuracy: 0.7778
# Epoch 41/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0477 - accuracy: 0.9815 - val_loss: 1.0413 - val_accuracy: 0.8254
# Epoch 42/50
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0561 - accuracy: 0.9824 - val_loss: 0.9193 - val_accuracy: 0.8095
# Epoch 43/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0581 - accuracy: 0.9790 - val_loss: 1.3146 - val_accuracy: 0.8095
# Epoch 44/50
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0632 - accuracy: 0.9799 - val_loss: 1.1065 - val_accuracy: 0.8095
# Epoch 45/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0376 - accuracy: 0.9887 - val_loss: 1.2436 - val_accuracy: 0.7937
# Epoch 46/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0338 - accuracy: 0.9891 - val_loss: 1.2326 - val_accuracy: 0.8095
# Epoch 47/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0309 - accuracy: 0.9916 - val_loss: 1.1781 - val_accuracy: 0.8254
# Epoch 48/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0474 - accuracy: 0.9866 - val_loss: 1.1519 - val_accuracy: 0.8254
# Epoch 49/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0351 - accuracy: 0.9891 - val_loss: 1.2484 - val_accuracy: 0.8254
# Epoch 50/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0428 - accuracy: 0.9862 - val_loss: 1.2828 - val_accuracy: 0.8254
# Epoch 1/50
# 248/248 [==============================] - 2s 6ms/step - loss: 0.8798 - accuracy: 0.7133 - val_loss: 0.3682 - val_accuracy: 0.8702
# Epoch 2/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.5054 - accuracy: 0.8306 - val_loss: 0.2679 - val_accuracy: 0.9084
# Epoch 3/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.4220 - accuracy: 0.8476 - val_loss: 0.1917 - val_accuracy: 0.9389
# Epoch 4/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.3502 - accuracy: 0.8786 - val_loss: 0.1498 - val_accuracy: 0.9389
# Epoch 5/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.3057 - accuracy: 0.8903 - val_loss: 0.1564 - val_accuracy: 0.9542
# Epoch 6/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.2801 - accuracy: 0.8952 - val_loss: 0.1326 - val_accuracy: 0.9695
# Epoch 7/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.2275 - accuracy: 0.9149 - val_loss: 0.1074 - val_accuracy: 0.9618
# Epoch 8/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.2271 - accuracy: 0.9206 - val_loss: 0.0899 - val_accuracy: 0.9695
# Epoch 9/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.1966 - accuracy: 0.9343 - val_loss: 0.0951 - val_accuracy: 0.9695
# Epoch 10/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.1741 - accuracy: 0.9367 - val_loss: 0.0940 - val_accuracy: 0.9695
# Epoch 11/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.1565 - accuracy: 0.9444 - val_loss: 0.1072 - val_accuracy: 0.9466
# Epoch 12/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.1548 - accuracy: 0.9403 - val_loss: 0.0654 - val_accuracy: 0.9847
# Epoch 13/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.1301 - accuracy: 0.9540 - val_loss: 0.0926 - val_accuracy: 0.9695
# Epoch 14/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.1249 - accuracy: 0.9516 - val_loss: 0.0786 - val_accuracy: 0.9695
# Epoch 15/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.1111 - accuracy: 0.9601 - val_loss: 0.0767 - val_accuracy: 0.9466
# Epoch 16/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.1112 - accuracy: 0.9637 - val_loss: 0.0396 - val_accuracy: 0.9924
# Epoch 17/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0916 - accuracy: 0.9661 - val_loss: 0.0637 - val_accuracy: 0.9847
# Epoch 18/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.1041 - accuracy: 0.9589 - val_loss: 0.0914 - val_accuracy: 0.9771
# Epoch 19/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0926 - accuracy: 0.9645 - val_loss: 0.0835 - val_accuracy: 0.9618
# Epoch 20/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0784 - accuracy: 0.9702 - val_loss: 0.0703 - val_accuracy: 0.9771
# Epoch 21/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0698 - accuracy: 0.9758 - val_loss: 0.0598 - val_accuracy: 0.9771
# Epoch 22/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0937 - accuracy: 0.9673 - val_loss: 0.0483 - val_accuracy: 0.9618
# Epoch 23/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0642 - accuracy: 0.9815 - val_loss: 0.0443 - val_accuracy: 0.9847
# Epoch 24/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0762 - accuracy: 0.9714 - val_loss: 0.0608 - val_accuracy: 0.9771
# Epoch 25/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0801 - accuracy: 0.9726 - val_loss: 0.0589 - val_accuracy: 0.9771
# Epoch 26/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0812 - accuracy: 0.9681 - val_loss: 0.0757 - val_accuracy: 0.9771
# Epoch 27/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0593 - accuracy: 0.9823 - val_loss: 0.0432 - val_accuracy: 0.9847
# Epoch 28/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0502 - accuracy: 0.9879 - val_loss: 0.0633 - val_accuracy: 0.9847
# Epoch 29/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0582 - accuracy: 0.9786 - val_loss: 0.0840 - val_accuracy: 0.9847
# Epoch 30/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0510 - accuracy: 0.9835 - val_loss: 0.0620 - val_accuracy: 0.9771
# Epoch 31/50
# 248/248 [==============================] - 1s 3ms/step - loss: 0.0487 - accuracy: 0.9831 - val_loss: 0.0662 - val_accuracy: 0.9847
# Epoch 32/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0504 - accuracy: 0.9839 - val_loss: 0.0759 - val_accuracy: 0.9771
# Epoch 33/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0577 - accuracy: 0.9794 - val_loss: 0.0787 - val_accuracy: 0.9847
# Epoch 34/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0630 - accuracy: 0.9810 - val_loss: 0.0794 - val_accuracy: 0.9847
# Epoch 35/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0524 - accuracy: 0.9802 - val_loss: 0.0407 - val_accuracy: 0.9771
# Epoch 36/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0546 - accuracy: 0.9806 - val_loss: 0.0747 - val_accuracy: 0.9771
# Epoch 37/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0602 - accuracy: 0.9794 - val_loss: 0.0513 - val_accuracy: 0.9847
# Epoch 38/50
# 248/248 [==============================] - 2s 7ms/step - loss: 0.0636 - accuracy: 0.9794 - val_loss: 0.1038 - val_accuracy: 0.9771
# Epoch 39/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0637 - accuracy: 0.9798 - val_loss: 0.0316 - val_accuracy: 0.9847
# Epoch 40/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0660 - accuracy: 0.9794 - val_loss: 0.0284 - val_accuracy: 0.9924
# Epoch 41/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0468 - accuracy: 0.9831 - val_loss: 0.0591 - val_accuracy: 0.9847
# Epoch 42/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0439 - accuracy: 0.9798 - val_loss: 0.0914 - val_accuracy: 0.9695
# Epoch 43/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0528 - accuracy: 0.9798 - val_loss: 0.0598 - val_accuracy: 0.9771
# Epoch 44/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0531 - accuracy: 0.9843 - val_loss: 0.0986 - val_accuracy: 0.9771
# Epoch 45/50
# 248/248 [==============================] - 1s 4ms/step - loss: 0.0352 - accuracy: 0.9871 - val_loss: 0.0913 - val_accuracy: 0.9771
# Epoch 46/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0335 - accuracy: 0.9891 - val_loss: 0.0708 - val_accuracy: 0.9771
# Epoch 47/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0228 - accuracy: 0.9911 - val_loss: 0.0457 - val_accuracy: 0.9771
# Epoch 48/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0306 - accuracy: 0.9899 - val_loss: 0.0664 - val_accuracy: 0.9771
# Epoch 49/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0430 - accuracy: 0.9827 - val_loss: 0.0641 - val_accuracy: 0.9847
# Epoch 50/50
# 248/248 [==============================] - 1s 5ms/step - loss: 0.0692 - accuracy: 0.9770 - val_loss: 0.0822 - val_accuracy: 0.9771

# %%
# Avaliação dos modelos
print(return_accuracy(model_10, y_test_10, X_test_10))
print(return_accuracy(model_10_over, y_test_10, X_test_10))
# Out:
# (0.856687898089172, 0.8324256460335624, 0.8248332706685816)
# (0.8375796178343949, 0.833539391923867, 0.8322397820499386)

# %% [markdown]
# # Modelo com 12 Classes

# %%
# Treinamento com 12 labels
parent_labels_12 = ['label:COOKING','label:SITTING','label:LYING_DOWN','label:FIX_running','label:FIX_walking','label:BICYCLING', 'label:WATCHING_TV', 'label:SURFING_THE_INTERNET', 'label:COMPUTER_WORK', 'label:LOC_home', 'label:TALKING','label:DRIVE_-_I_M_THE_DRIVER']

for i in range(len(parent_labels_12)):
    data = dataset[parent_labels_12[i]]
    print(parent_labels_12[i])
    #print(data.value_counts())
    
print(len(parent_labels_12))
# Out:
# label:COOKING
# label:SITTING
# label:LYING_DOWN
# label:FIX_running
# label:FIX_walking
# label:BICYCLING
# label:WATCHING_TV
# label:SURFING_THE_INTERNET
# label:COMPUTER_WORK
# label:LOC_home
# label:TALKING
# label:DRIVE_-_I_M_THE_DRIVER
# 12

# %%
# Limpeza dos dados e seleção para aplicar ao modelo
X_parent_12, y_parent_12 = data_cleaner(dataset, feature_set_range, parent_labels_12)
print(X_parent_12.shape)
print(y_parent_12.shape)
# Out:
# 3170
# 12
# (3170, 217)
# (3170,)

# %%
# Observação da frequencia das classes
y_df_12 = pd.DataFrame(y_parent_12)
print(y_df_12.value_counts())
# Out:
# 1     1321
# 9      768
# 5      442
# 2      244
# 4      214
# 0      119
# 10      32
# 3       30
# dtype: int64

# %%
#Separando em treino e teste para 10 labels
X_train_12, X_test_12, y_train_12, y_test_12 = train_test_split(X_parent_12, y_parent_12, test_size=test_split, random_state = seed, stratify=y_parent_12)

# %%
# Definindo a estratégia de oversample para 12 labels
counter = Counter(y_train_12)
print(counter)
oversample = SMOTE(sampling_strategy={1:1057, 9:614, 5:400, 2:200, 4:200, 0:100, 3: 40, 10:40})
#Aplicando a reamostragem nos conjuntos X e Y
X_over_12, y_over_12 = oversample.fit_resample(X_train_12, y_train_12)
print(y_over_12.shape)
# Out:
# Counter({1: 1057, 9: 614, 5: 354, 2: 195, 4: 171, 0: 95, 10: 26, 3: 24})
# (2651,)

# %%
# Treinamento dos modelos
model_12 = run_dnn(X_train_12, y_train_12, 12)
model_12_over = run_dnn(X_over_12, y_over_12, 12)
# Out:
# Epoch 1/50
# 241/241 [==============================] - 2s 5ms/step - loss: 0.9334 - accuracy: 0.7040 - val_loss: 0.6756 - val_accuracy: 0.7480
# Epoch 2/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.5530 - accuracy: 0.8174 - val_loss: 0.6013 - val_accuracy: 0.7559
# Epoch 3/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.4619 - accuracy: 0.8443 - val_loss: 0.6237 - val_accuracy: 0.7717
# Epoch 4/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.3959 - accuracy: 0.8655 - val_loss: 0.5921 - val_accuracy: 0.7717
# Epoch 5/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.3457 - accuracy: 0.8800 - val_loss: 0.5149 - val_accuracy: 0.7795
# Epoch 6/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.2909 - accuracy: 0.9016 - val_loss: 0.5313 - val_accuracy: 0.7559
# Epoch 7/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.2596 - accuracy: 0.9087 - val_loss: 0.5081 - val_accuracy: 0.8031
# Epoch 8/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.2363 - accuracy: 0.9191 - val_loss: 0.5976 - val_accuracy: 0.7874
# Epoch 9/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.2195 - accuracy: 0.9228 - val_loss: 0.5299 - val_accuracy: 0.8031
# Epoch 10/50
# 241/241 [==============================] - 1s 3ms/step - loss: 0.1906 - accuracy: 0.9332 - val_loss: 0.5283 - val_accuracy: 0.8031
# Epoch 11/50
# 241/241 [==============================] - 1s 3ms/step - loss: 0.1845 - accuracy: 0.9352 - val_loss: 0.6130 - val_accuracy: 0.7795
# Epoch 12/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.1592 - accuracy: 0.9435 - val_loss: 0.5599 - val_accuracy: 0.8110
# Epoch 13/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.1502 - accuracy: 0.9448 - val_loss: 0.6860 - val_accuracy: 0.7874
# Epoch 14/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.1408 - accuracy: 0.9481 - val_loss: 0.5994 - val_accuracy: 0.7953
# Epoch 15/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.1261 - accuracy: 0.9543 - val_loss: 0.6582 - val_accuracy: 0.8110
# Epoch 16/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.1211 - accuracy: 0.9581 - val_loss: 0.6586 - val_accuracy: 0.8110
# Epoch 17/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.1105 - accuracy: 0.9631 - val_loss: 0.5629 - val_accuracy: 0.8346
# Epoch 18/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.1234 - accuracy: 0.9581 - val_loss: 0.6676 - val_accuracy: 0.8268
# Epoch 19/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.1139 - accuracy: 0.9610 - val_loss: 0.6117 - val_accuracy: 0.8425
# Epoch 20/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.0888 - accuracy: 0.9693 - val_loss: 0.7257 - val_accuracy: 0.8346
# Epoch 21/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0864 - accuracy: 0.9672 - val_loss: 0.7330 - val_accuracy: 0.8110
# Epoch 22/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.0975 - accuracy: 0.9755 - val_loss: 0.7755 - val_accuracy: 0.8031
# Epoch 23/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0777 - accuracy: 0.9768 - val_loss: 0.6470 - val_accuracy: 0.8425
# Epoch 24/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0801 - accuracy: 0.9788 - val_loss: 0.7422 - val_accuracy: 0.8110
# Epoch 25/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0895 - accuracy: 0.9680 - val_loss: 0.7255 - val_accuracy: 0.7953
# Epoch 26/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0908 - accuracy: 0.9685 - val_loss: 0.6943 - val_accuracy: 0.8425
# Epoch 27/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.0767 - accuracy: 0.9726 - val_loss: 0.6110 - val_accuracy: 0.8268
# Epoch 28/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0728 - accuracy: 0.9763 - val_loss: 0.7341 - val_accuracy: 0.8268
# Epoch 29/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.0709 - accuracy: 0.9738 - val_loss: 0.7454 - val_accuracy: 0.8346
# Epoch 30/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0569 - accuracy: 0.9784 - val_loss: 0.7016 - val_accuracy: 0.8583
# Epoch 31/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.0638 - accuracy: 0.9830 - val_loss: 0.8027 - val_accuracy: 0.8425
# Epoch 32/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0735 - accuracy: 0.9763 - val_loss: 0.7235 - val_accuracy: 0.8346
# Epoch 33/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0684 - accuracy: 0.9726 - val_loss: 0.5944 - val_accuracy: 0.8504
# Epoch 34/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0699 - accuracy: 0.9780 - val_loss: 0.6345 - val_accuracy: 0.8346
# Epoch 35/50
# 241/241 [==============================] - 1s 3ms/step - loss: 0.0540 - accuracy: 0.9851 - val_loss: 0.7579 - val_accuracy: 0.8031
# Epoch 36/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.0741 - accuracy: 0.9755 - val_loss: 0.6831 - val_accuracy: 0.8346
# Epoch 37/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0485 - accuracy: 0.9838 - val_loss: 0.6402 - val_accuracy: 0.8346
# Epoch 38/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.0494 - accuracy: 0.9813 - val_loss: 0.6879 - val_accuracy: 0.8661
# Epoch 39/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0532 - accuracy: 0.9826 - val_loss: 0.7366 - val_accuracy: 0.8504
# Epoch 40/50
# 241/241 [==============================] - 1s 3ms/step - loss: 0.0545 - accuracy: 0.9842 - val_loss: 0.7002 - val_accuracy: 0.8346
# Epoch 41/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.0407 - accuracy: 0.9859 - val_loss: 0.8442 - val_accuracy: 0.8425
# Epoch 42/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0448 - accuracy: 0.9846 - val_loss: 0.6641 - val_accuracy: 0.8504
# Epoch 43/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0459 - accuracy: 0.9838 - val_loss: 0.8817 - val_accuracy: 0.8425
# Epoch 44/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.0609 - accuracy: 0.9763 - val_loss: 0.8836 - val_accuracy: 0.8346
# Epoch 45/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0522 - accuracy: 0.9805 - val_loss: 0.9375 - val_accuracy: 0.8346
# Epoch 46/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0621 - accuracy: 0.9776 - val_loss: 0.9294 - val_accuracy: 0.8346
# Epoch 47/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0338 - accuracy: 0.9871 - val_loss: 0.8156 - val_accuracy: 0.8189
# Epoch 48/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.0396 - accuracy: 0.9875 - val_loss: 0.8961 - val_accuracy: 0.8189
# Epoch 49/50
# 241/241 [==============================] - 1s 4ms/step - loss: 0.0360 - accuracy: 0.9875 - val_loss: 0.8421 - val_accuracy: 0.8425
# Epoch 50/50
# 241/241 [==============================] - 1s 5ms/step - loss: 0.0268 - accuracy: 0.9925 - val_loss: 0.9175 - val_accuracy: 0.8189
# Epoch 1/50
# 252/252 [==============================] - 2s 5ms/step - loss: 1.0118 - accuracy: 0.6851 - val_loss: 0.6818 - val_accuracy: 0.7444
# Epoch 2/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.5864 - accuracy: 0.8034 - val_loss: 0.3977 - val_accuracy: 0.8647
# Epoch 3/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.4731 - accuracy: 0.8364 - val_loss: 0.3284 - val_accuracy: 0.8647
# Epoch 4/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4161 - accuracy: 0.8515 - val_loss: 0.2755 - val_accuracy: 0.9173
# Epoch 5/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.3485 - accuracy: 0.8844 - val_loss: 0.2180 - val_accuracy: 0.9323
# Epoch 6/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.3047 - accuracy: 0.8967 - val_loss: 0.1808 - val_accuracy: 0.9323
# Epoch 7/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.2517 - accuracy: 0.9114 - val_loss: 0.1229 - val_accuracy: 0.9624
# Epoch 8/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.2481 - accuracy: 0.9098 - val_loss: 0.1108 - val_accuracy: 0.9624
# Epoch 9/50
# 252/252 [==============================] - 1s 3ms/step - loss: 0.2243 - accuracy: 0.9174 - val_loss: 0.1241 - val_accuracy: 0.9624
# Epoch 10/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1930 - accuracy: 0.9357 - val_loss: 0.0903 - val_accuracy: 0.9774
# Epoch 11/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1673 - accuracy: 0.9384 - val_loss: 0.0954 - val_accuracy: 0.9624
# Epoch 12/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1708 - accuracy: 0.9392 - val_loss: 0.1041 - val_accuracy: 0.9474
# Epoch 13/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1463 - accuracy: 0.9476 - val_loss: 0.0815 - val_accuracy: 0.9624
# Epoch 14/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1372 - accuracy: 0.9543 - val_loss: 0.0674 - val_accuracy: 0.9624
# Epoch 15/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1213 - accuracy: 0.9563 - val_loss: 0.0551 - val_accuracy: 0.9774
# Epoch 16/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1347 - accuracy: 0.9488 - val_loss: 0.0791 - val_accuracy: 0.9699
# Epoch 17/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1045 - accuracy: 0.9603 - val_loss: 0.1100 - val_accuracy: 0.9549
# Epoch 18/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.0910 - accuracy: 0.9690 - val_loss: 0.0928 - val_accuracy: 0.9774
# Epoch 19/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1101 - accuracy: 0.9651 - val_loss: 0.1065 - val_accuracy: 0.9699
# Epoch 20/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1074 - accuracy: 0.9682 - val_loss: 0.0887 - val_accuracy: 0.9699
# Epoch 21/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0831 - accuracy: 0.9738 - val_loss: 0.0598 - val_accuracy: 0.9850
# Epoch 22/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0908 - accuracy: 0.9698 - val_loss: 0.0832 - val_accuracy: 0.9774
# Epoch 23/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0733 - accuracy: 0.9742 - val_loss: 0.1186 - val_accuracy: 0.9699
# Epoch 24/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0936 - accuracy: 0.9674 - val_loss: 0.0925 - val_accuracy: 0.9624
# Epoch 25/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0848 - accuracy: 0.9710 - val_loss: 0.0940 - val_accuracy: 0.9774
# Epoch 26/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.0510 - accuracy: 0.9797 - val_loss: 0.1150 - val_accuracy: 0.9774
# Epoch 27/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.0602 - accuracy: 0.9801 - val_loss: 0.0836 - val_accuracy: 0.9699
# Epoch 28/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0600 - accuracy: 0.9793 - val_loss: 0.0829 - val_accuracy: 0.9774
# Epoch 29/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.0935 - accuracy: 0.9694 - val_loss: 0.1887 - val_accuracy: 0.9624
# Epoch 30/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.0637 - accuracy: 0.9805 - val_loss: 0.1026 - val_accuracy: 0.9774
# Epoch 31/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0663 - accuracy: 0.9786 - val_loss: 0.0902 - val_accuracy: 0.9774
# Epoch 32/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.0501 - accuracy: 0.9829 - val_loss: 0.0940 - val_accuracy: 0.9774
# Epoch 33/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0444 - accuracy: 0.9825 - val_loss: 0.0772 - val_accuracy: 0.9850
# Epoch 34/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0416 - accuracy: 0.9877 - val_loss: 0.0910 - val_accuracy: 0.9850
# Epoch 35/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0612 - accuracy: 0.9774 - val_loss: 0.1043 - val_accuracy: 0.9925
# Epoch 36/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0655 - accuracy: 0.9786 - val_loss: 0.0823 - val_accuracy: 0.9850
# Epoch 37/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.0609 - accuracy: 0.9790 - val_loss: 0.1023 - val_accuracy: 0.9774
# Epoch 38/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.0815 - accuracy: 0.9790 - val_loss: 0.1075 - val_accuracy: 0.9774
# Epoch 39/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0806 - accuracy: 0.9782 - val_loss: 0.0731 - val_accuracy: 0.9850
# Epoch 40/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0550 - accuracy: 0.9805 - val_loss: 0.0754 - val_accuracy: 0.9699
# Epoch 41/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0600 - accuracy: 0.9786 - val_loss: 0.1367 - val_accuracy: 0.9774
# Epoch 42/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0497 - accuracy: 0.9817 - val_loss: 0.1253 - val_accuracy: 0.9699
# Epoch 43/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0597 - accuracy: 0.9793 - val_loss: 0.0796 - val_accuracy: 0.9850
# Epoch 44/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0439 - accuracy: 0.9877 - val_loss: 0.0927 - val_accuracy: 0.9774
# Epoch 45/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0366 - accuracy: 0.9893 - val_loss: 0.0848 - val_accuracy: 0.9774
# Epoch 46/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.0538 - accuracy: 0.9833 - val_loss: 0.1191 - val_accuracy: 0.9774
# Epoch 47/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0415 - accuracy: 0.9841 - val_loss: 0.1273 - val_accuracy: 0.9774
# Epoch 48/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.0579 - accuracy: 0.9829 - val_loss: 0.1239 - val_accuracy: 0.9699
# Epoch 49/50
# 252/252 [==============================] - 1s 5ms/step - loss: 0.0423 - accuracy: 0.9905 - val_loss: 0.1141 - val_accuracy: 0.9774
# Epoch 50/50
# 252/252 [==============================] - 1s 4ms/step - loss: 0.0380 - accuracy: 0.9865 - val_loss: 0.1185 - val_accuracy: 0.9774

# %%
# Avaliação dos modelos
print(return_accuracy(model_12, y_test_12, X_test_12))
print(return_accuracy(model_12_over, y_test_12, X_test_12))
# Out:
# (0.8564668769716088, 0.8217526497358838, 0.8168690044728251)
# (0.8470031545741324, 0.8037060020229683, 0.8188788993398628)
